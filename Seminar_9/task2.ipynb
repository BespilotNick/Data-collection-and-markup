# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../tweets.csv', engine='python', encoding='utf-8', on_bad_lines='skip', encoding_errors='ignore')

# %%
subset = df.sample(frac=0.1)

# %%
subset
# Out:
#                         id                                    user_name  \
# 8374   1396098700678549508  Jasmine |Back in Dubai |Fully Vaccinated|❣️
# 10106  1430606784775999491                                   Miss Ivana
# 793    1340304234416381954                           Senator Shehu Sani
# 5537   1360913457571364864                                    john dyer
# 10503  1442967733222604808                     President-Elect Sandwich
# ...                    ...                                          ...
# 84     1338565957866778624                             Genevieve Reaume
# 4715   1354652570963197954                            Brian Wang, Ph.D.
# 2070   1344992970257399809                              A Slight Return
# 7623   1377716200784994305                                       iksule
# 10194  1432833416949641221                             ChristinaDeweyMD
#
#                        user_location  \
# 8374     Dubai, United Arab Emirates
# ...

# %%
subset.shape
# Out:
# (1102, 16)

# %%
subset.to_csv('../tweets_subset.csv', index=False)
